# %% [markdown]
# PROBLEM STATEMENT

# %% [markdown]
# INX Future Inc , (referred as INX ) , is one of the leading data analytics and automation solutions provider with over 15 years of global business presence. INX is consistently rated as top 20 best employers past 5 years. INX human resource policies are considered as employee friendly and widely perceived as best practices in the industry.
#
# Recent years, the employee performance indexes are not healthy and this is becoming a growing concerns among the top management. There has been increased escalations on service delivery and client satisfaction levels came down by 8 percentage points.
#
# CEO, Mr. Brain, knows the issues but concerned to take any actions in penalizing non-performing employees as this would affect the employee morale of all the employees in general and may further reduce the performance. Also, the market perception best employer and thereby attracting best talents to join the company.
#
# Mr. Brain decided to initiate a data science project , which analyses the current employee data and find the core underlying causes of this performance issues. Mr. Brain, being a data scientist himself, expects the findings of this project will help him to take right course of actions. He also expects a clear indicators of non performing employees, so that any penalization of non-performing employee, if required, may not significantly affect other employee morals

# %%
import pandas as pd
import seaborn as sns
df = pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')

# %%
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
sns.boxplot(df['Age'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
df['EducationBackground'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['MaritalStatus'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='MaritalStatus'>

# %%
df['EmpDepartment'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df['EmpJobRole'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df['BusinessTravelFrequency'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
pd.crosstab(df['BusinessTravelFrequency'],df['EmpDepartment'])
# Out:
# EmpDepartment            Data Science  Development  Finance  Human Resources  \
# BusinessTravelFrequency
# Non-Travel                          0           35        4                5
# Travel_Frequently                   3           64        8               10
# Travel_Rarely                      17          262       37               39
#
# EmpDepartment            Research & Development  Sales
# BusinessTravelFrequency
# Non-Travel                                   47     41
# Travel_Frequently                            72     65
# Travel_Rarely                               224    267

# %%
sns.heatmap(pd.crosstab(df['BusinessTravelFrequency'],df['EmpDepartment']))
# Out:
# <AxesSubplot:xlabel='EmpDepartment', ylabel='BusinessTravelFrequency'>

# %%
sns.boxplot(df['DistanceFromHome'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DistanceFromHome'>

# %%
df['EmpEducationLevel'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['OverTime'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='OverTime'>

# %%
df['Attrition'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(df['EmpJobInvolvement'],df['EmpDepartment'],hue=df['Gender'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpJobInvolvement', ylabel='EmpDepartment'>

# %%
sns.barplot(df['EmpJobSatisfaction'],df['EmpJobRole'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpJobSatisfaction', ylabel='EmpJobRole'>

# %%
sns.barplot(df['EmpEducationLevel'],df['EmpDepartment'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpEducationLevel', ylabel='EmpDepartment'>

# %%
sns.lineplot(df['ExperienceYearsInCurrentRole'],df['EmpJobSatisfaction'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsInCurrentRole', ylabel='EmpJobSatisfaction'>

# %%
sns.barplot(df['EmpJobSatisfaction'],df['EmpDepartment'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpJobSatisfaction', ylabel='EmpDepartment'>

# %%
sns.scatterplot(df['TotalWorkExperienceInYears'],df['ExperienceYearsAtThisCompany'],hue=df['Gender'],size=df['EmpWorkLifeBalance'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalWorkExperienceInYears', ylabel='ExperienceYearsAtThisCompany'>

# %% [markdown]
# PROBLEM:
# EMPLOYEES LACK OF SKILLS
#
# The below five graphs clearly indicates that employees work life balance is not good, as they trained all the same way, there might be issue in lack of knowledge or skills in employees.
#
# SOLUTION:
# Training employees properly by correcty identifying the pain point can solve this issue.

# %%
sns.barplot(df['TrainingTimesLastYear'],df['EmpJobRole'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='EmpJobRole'>

# %%
sns.lineplot(df['EmpJobInvolvement'],df['TrainingTimesLastYear'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpJobInvolvement', ylabel='TrainingTimesLastYear'>

# %%
sns.boxplot(df['TrainingTimesLastYear'],df['EmpJobLevel'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='EmpJobLevel'>

# %%
sns.lineplot(df['TrainingTimesLastYear'],df['EmpJobSatisfaction'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='EmpJobSatisfaction'>

# %%
sns.lineplot(df['TrainingTimesLastYear'],df['EmpWorkLifeBalance'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='EmpWorkLifeBalance'>

# %% [markdown]
# PROBLEM:
# EMPLOYEES AREN'T MOTIVATED
#
# In the below 5 graphs we can see that employees are not recognized to their work and they are not satisfied, reason they aren't recongnized by the manangement.
#
#
# SOLUTION:
# Management team needs to recognize the work and promote the employees

# %%
sns.lineplot(df['DistanceFromHome'],df['EmpEnvironmentSatisfaction'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='EmpEnvironmentSatisfaction'>

# %%
sns.lineplot(df['DistanceFromHome'],df['EmpJobSatisfaction'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='EmpJobSatisfaction'>

# %%
sns.lineplot(df['DistanceFromHome'],df['EmpRelationshipSatisfaction'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='EmpRelationshipSatisfaction'>

# %%
sns.lineplot(df['DistanceFromHome'],df['YearsSinceLastPromotion'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='YearsSinceLastPromotion'>

# %%
sns.lineplot(df['DistanceFromHome'],df['ExperienceYearsAtThisCompany'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='ExperienceYearsAtThisCompany'>

# %% [markdown]
# PROBLEM:
# Experience in the current role of employee should linearly increase their salary hike and job satisfaction, as you can see in the graph performance rating of employee should increase, but it is not. Have a look on below 5 graphs
#
#
# SOLUTION:
# Management needs to increase the salary, as per experience and performance

# %%
sns.lineplot(df['ExperienceYearsInCurrentRole'],df['EmpJobSatisfaction'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsInCurrentRole', ylabel='EmpJobSatisfaction'>

# %%
sns.lineplot(df['ExperienceYearsInCurrentRole'],df['EmpLastSalaryHikePercent'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsInCurrentRole', ylabel='EmpLastSalaryHikePercent'>

# %%
sns.lineplot(df['ExperienceYearsInCurrentRole'],df['EmpJobInvolvement'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsInCurrentRole', ylabel='EmpJobInvolvement'>

# %%
sns.lineplot(df['ExperienceYearsInCurrentRole'],df['EmpEnvironmentSatisfaction'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsInCurrentRole', ylabel='EmpEnvironmentSatisfaction'>

# %%
sns.lineplot(df['ExperienceYearsInCurrentRole'],df['PerformanceRating'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsInCurrentRole', ylabel='PerformanceRating'>

# %% [markdown]
# PROBLEM:
# All employees showing constant involvement with respect to thier domains.
#
# SOLUTION:
# Management needs to gives bonus or rewards for every task done to improve the efficiency of work

# %%
sns.boxplot(df['EmpJobInvolvement'],df['EmpJobRole'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpJobInvolvement', ylabel='EmpJobRole'>

# %%
sns.boxplot(df['EmpJobInvolvement'],df['EmpDepartment'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpJobInvolvement', ylabel='EmpDepartment'>

# %%
sns.boxplot(df['EmpJobInvolvement'],df['TotalWorkExperienceInYears'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpJobInvolvement', ylabel='TotalWorkExperienceInYears'>

# %% [markdown]
# PROBLEM:
# No salary hike even after overtime work, divorced employees worked more, even thou maintaining the
# good experience with management, management failed to give the emp job satisfaction.
#
# SOLUTION:
# Motivate employees by paying extra salary and provide bonus for overtime

# %%
sns.lineplot(df['ExperienceYearsAtThisCompany'],df['YearsSinceLastPromotion'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsAtThisCompany', ylabel='YearsSinceLastPromotion'>

# %%
sns.lineplot(df['ExperienceYearsAtThisCompany'],df['PerformanceRating'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsAtThisCompany', ylabel='PerformanceRating'>

# %%
sns.lineplot(df['ExperienceYearsAtThisCompany'],df['EmpLastSalaryHikePercent'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsAtThisCompany', ylabel='EmpLastSalaryHikePercent'>

# %%
sns.barplot(df['ExperienceYearsAtThisCompany'],df['OverTime'],hue=df['Gender'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsAtThisCompany', ylabel='OverTime'>

# %%
sns.barplot(df['ExperienceYearsAtThisCompany'],df['OverTime'],hue=df['MaritalStatus'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsAtThisCompany', ylabel='OverTime'>

# %%
sns.barplot(df['ExperienceYearsAtThisCompany'],df['Attrition'],hue=df['OverTime'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsAtThisCompany', ylabel='Attrition'>

# %%
sns.lineplot(df['YearsWithCurrManager'],df['EmpEnvironmentSatisfaction'])
# Out:
# C:\Users\Sikandar Basha k S\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='EmpEnvironmentSatisfaction'>

# %% [markdown]
# According to me no need to of penalization, employees are working decent good, they need to recognize their work
# and get promated. Management team needs to look after the performance of employees and needs to provide
# salary hike and bonuses to keep employees motivated..
